# %%
#CPU만 사용
from ultralytics import YOLO

model = YOLO("yolov8s.pt")


model.train(data = r"C:/Users/kimyo/datasets/data.yaml", epochs=100, batch=16, workers=8, name="smile_angry_yolov8")
# Out:
# ...
# Ultralytics 8.3.252  Python-3.11.14 torch-2.9.1+cpu CPU (AMD Ryzen 5 5600 6-Core Processor)
# ...

# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.5.1+cu121
# True
# NVIDIA GeForce RTX 4060 Ti

# %%
#GPU(CUDA) 사용
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data=r"C:/Users/kimyo/datasets/data.yaml",
    epochs=100,
    imgsz=640,
    batch=32,        # RTX 4060 Ti → 가능성 높음
    device=0,        # GPU
    workers=8,
    cache=True,
    name="happy_blank_yolov8"
)
# Out:
# ...
# Ultralytics 8.3.252  Python-3.11.14 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# ...

# %%
#Finetuning
from ultralytics import YOLO

model = YOLO(r"C:/Users/kimyo/runs/detect/happy_blank_yolov8/weights/best.pt")

model.train(
    data=r"C:/Users/kimyo/datasets/data.yaml",
    epochs=50,
    imgsz=640,
    batch=32,
    device=0,
    workers=8,
    cache=True,
    lr0=0.001,          # 🔑 미세조정
    name="smile_angry_ft"
)
# Out:
# Ultralytics 8.3.252  Python-3.11.14 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# ...

# %%
#Resume
from ultralytics import YOLO

# last.pt 로드
model = YOLO(r"C:/Users/kimyo/runs/detect/happy_blank_yolov8/weights/last.pt")

# 이어서 학습
model.train(
    resume=True
)
# Out:
# Ultralytics 8.3.252  Python-3.11.14 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# ...
